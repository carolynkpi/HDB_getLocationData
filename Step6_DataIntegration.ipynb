# %% [markdown]
# # Step 6: Data Integration

# %% [markdown]
# ## Import Libraries

# %%
import os
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# Here are the columns we need for each unique HDB address. <br>
# 1. Nearest MRT/LRT station (and its relevant info, eg: MRT service line)
# 2. Radial distance to nearest MRT station.
# 3. Walking distance to nearest MRT station.
# 4. Walking time to nearest MRT station. <br><br>
# ***Within 500m and 1km***
# 5. Number of MRT/LRT stations nearby.
# 6. Number of bus stations nearby.
# 7. Number of schools nearby.
# 8. Number of food places nearby.
# 9. Number of shopping places nearby.

# %% [markdown]
# ## User Inputs

# %%
outputFile = 'googleOutput_20180319.csv'
nearestMRT = 'nearest_MRT_20180311.csv'
walkingDistance = 'walking_distances_compiled_20180317.csv' # to be replaced. 
MRT = 'MRT.csv'

placesBegin = 'places_2018' 
fileType = 'csv'
placeFilelist = []
for f in os.listdir(): 
    if f[0: len(placesBegin)] == placesBegin and f.split('.')[-1] == fileType:
        placeFilelist.append(f)

# Comment out following line for full run
#placeFilelist = placeFilelist[0:2]     

placeFilelist
# Out:
# ['places_20180311.csv',
#  'places_20180311_2.csv',
#  'places_20180311_3.csv',
#  'places_20180311_4.csv',
#  'places_20180311_5.csv',
#  'places_20180315_1.csv',
#  'places_20180315_2.csv',
#  'places_20180315_3.csv',
#  'places_20180315_4.csv']

# %% [markdown]
# ## Read Relevant Files

# %%
df1 = pd.read_csv(nearestMRT)
df1.set_index('HDB Address', inplace = True)
df2 = pd.read_csv(walkingDistance) 
df2.set_index('HDB Address', inplace = True)
df3 = pd.read_csv(MRT)
df3.set_index('Station Code', inplace = True)

# %%
df = df1.loc[:,['Nearest Station Code', 'Vincenty Distance in km']]
df = df.join(df2)

df['Station Match'] = np.where(df['Nearest Station Code'] == df['MRT Station Code'], True, False)
if len(df[df['Station Match'] == False]) != 0:
    print('WARNING: Nearest Station Code from radial distance not matching MRT Station Code from walking distance.')
else:
    df = df.drop('Nearest Station Code', axis = 1)
    
df3 = df3.drop(['Planning Area', 'Region','Connection to other transport means'], axis = 1)
df = df.join(df3, on = 'MRT Station Code')
# Out:
# WARNING: Nearest Station Code from radial distance not matching MRT Station Code from walking distance.

# %% [markdown]
# ## Special Treatment for Places

# %% [markdown]
# Setup to query the places results file.

# %%
placeTypes = ['bus_station', 'subway_station','cafe','restaurant','school','shopping_mall','supermarket','park']
distance = [1, 0.5]
placeID = {}
placeCount = {}
for d in distance:
    placeID[d] = dict(zip(placeTypes, [{}]*len(placeTypes)))
    placeCount[d] = dict(zip(placeTypes, [{}]*len(placeTypes)))    
placeDirectory = {}

# %% [markdown]
# Read places results file into a dictionary

# %%
f_t = 0
for f in placeFilelist: # loop for each file
    df4 = pd.read_csv(f) 
    
    for d in distance: # loop for each cut-off distance
        data = df4[df4['Place Distance in km'] <= d]
        
        # create a directory to map place ID to place name as we read the file.
        placeDir = data.loc[:, ['Place ID','PLace Name']].drop_duplicates(inplace = False)
        placeDir = dict(zip(placeDir['Place ID'].tolist(), placeDir['PLace Name'].tolist()))
        placeDirectory.update(placeDir)
        
        t_t = 0
        for t in placeTypes: # loop for each place type
            type_data = data[data['Place Type'] == t]
            
            place = placeID[d][t].copy()
            n = placeCount[d][t].copy()
                        
            index = type_data['HDB Address'].unique().tolist()
            for i in index: # loop for each HDB
                if i in place:
                    place[i] = np.unique(np.append(place[i], type_data.loc[type_data['HDB Address']==i, 'Place ID'].unique()))
                else: 
                    place[i] = type_data.loc[type_data['HDB Address']==i, 'Place ID'].unique()
                n[i] = place[i].shape[0]
                
            placeID[d][t] = place.copy()
            placeCount[d][t] = n.copy()
            t_t +=1
            print('Recorded for %i/%i types of places within %.1f km for File %s. ' %(t_t,len(placeTypes),d,f))
            
        print('Recorded for %.1f km distance for File %s. ' %(d,f))    
        
    f_t +=1
    print('Recorded %i/%i files ' %(f_t, len(placeFilelist)))
# Out:
# Recorded for 1/8 types of places within 1.0 km for File places_20180311.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180311.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180311.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180311.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180311.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180311.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180311.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180311.csv.
# Recorded for 1.0 km distance for File places_20180311.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180311.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180311.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180311.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180311.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180311.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180311.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180311.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180311.csv.
# Recorded for 0.5 km distance for File places_20180311.csv.
# Recorded 1/9 files
# Recorded for 1/8 types of places within 1.0 km for File places_20180311_2.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180311_2.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180311_2.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180311_2.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180311_2.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180311_2.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180311_2.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180311_2.csv.
# Recorded for 1.0 km distance for File places_20180311_2.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180311_2.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180311_2.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180311_2.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180311_2.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180311_2.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180311_2.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180311_2.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180311_2.csv.
# Recorded for 0.5 km distance for File places_20180311_2.csv.
# Recorded 2/9 files
# Recorded for 1/8 types of places within 1.0 km for File places_20180311_3.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180311_3.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180311_3.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180311_3.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180311_3.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180311_3.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180311_3.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180311_3.csv.
# Recorded for 1.0 km distance for File places_20180311_3.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180311_3.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180311_3.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180311_3.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180311_3.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180311_3.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180311_3.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180311_3.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180311_3.csv.
# Recorded for 0.5 km distance for File places_20180311_3.csv.
# Recorded 3/9 files
# Recorded for 1/8 types of places within 1.0 km for File places_20180311_4.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180311_4.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180311_4.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180311_4.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180311_4.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180311_4.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180311_4.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180311_4.csv.
# Recorded for 1.0 km distance for File places_20180311_4.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180311_4.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180311_4.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180311_4.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180311_4.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180311_4.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180311_4.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180311_4.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180311_4.csv.
# Recorded for 0.5 km distance for File places_20180311_4.csv.
# Recorded 4/9 files
# Recorded for 1/8 types of places within 1.0 km for File places_20180311_5.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180311_5.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180311_5.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180311_5.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180311_5.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180311_5.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180311_5.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180311_5.csv.
# Recorded for 1.0 km distance for File places_20180311_5.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180311_5.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180311_5.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180311_5.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180311_5.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180311_5.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180311_5.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180311_5.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180311_5.csv.
# Recorded for 0.5 km distance for File places_20180311_5.csv.
# Recorded 5/9 files
# Recorded for 1/8 types of places within 1.0 km for File places_20180315_1.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180315_1.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180315_1.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180315_1.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180315_1.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180315_1.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180315_1.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180315_1.csv.
# Recorded for 1.0 km distance for File places_20180315_1.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180315_1.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180315_1.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180315_1.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180315_1.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180315_1.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180315_1.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180315_1.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180315_1.csv.
# Recorded for 0.5 km distance for File places_20180315_1.csv.
# Recorded 6/9 files
# Recorded for 1/8 types of places within 1.0 km for File places_20180315_2.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180315_2.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180315_2.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180315_2.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180315_2.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180315_2.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180315_2.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180315_2.csv.
# Recorded for 1.0 km distance for File places_20180315_2.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180315_2.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180315_2.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180315_2.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180315_2.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180315_2.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180315_2.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180315_2.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180315_2.csv.
# Recorded for 0.5 km distance for File places_20180315_2.csv.
# Recorded 7/9 files
# Recorded for 1/8 types of places within 1.0 km for File places_20180315_3.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180315_3.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180315_3.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180315_3.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180315_3.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180315_3.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180315_3.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180315_3.csv.
# Recorded for 1.0 km distance for File places_20180315_3.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180315_3.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180315_3.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180315_3.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180315_3.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180315_3.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180315_3.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180315_3.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180315_3.csv.
# Recorded for 0.5 km distance for File places_20180315_3.csv.
# Recorded 8/9 files
# Recorded for 1/8 types of places within 1.0 km for File places_20180315_4.csv.
# Recorded for 2/8 types of places within 1.0 km for File places_20180315_4.csv.
# Recorded for 3/8 types of places within 1.0 km for File places_20180315_4.csv.
# Recorded for 4/8 types of places within 1.0 km for File places_20180315_4.csv.
# Recorded for 5/8 types of places within 1.0 km for File places_20180315_4.csv.
# Recorded for 6/8 types of places within 1.0 km for File places_20180315_4.csv.
# Recorded for 7/8 types of places within 1.0 km for File places_20180315_4.csv.
# Recorded for 8/8 types of places within 1.0 km for File places_20180315_4.csv.
# Recorded for 1.0 km distance for File places_20180315_4.csv.
# Recorded for 1/8 types of places within 0.5 km for File places_20180315_4.csv.
# Recorded for 2/8 types of places within 0.5 km for File places_20180315_4.csv.
# Recorded for 3/8 types of places within 0.5 km for File places_20180315_4.csv.
# Recorded for 4/8 types of places within 0.5 km for File places_20180315_4.csv.
# Recorded for 5/8 types of places within 0.5 km for File places_20180315_4.csv.
# Recorded for 6/8 types of places within 0.5 km for File places_20180315_4.csv.
# Recorded for 7/8 types of places within 0.5 km for File places_20180315_4.csv.
# Recorded for 8/8 types of places within 0.5 km for File places_20180315_4.csv.
# Recorded for 0.5 km distance for File places_20180315_4.csv.
# Recorded 9/9 files

# %% [markdown]
# Convert dictionaries into columns.

# %%
columns={}
index = list(df.index)

for d in distance:
    for t in placeTypes:
        column = {}
        for i in df.index:
            if i not in placeCount[d][t]:
                column[i] = 0
            else:
                column[i] = placeCount[d][t][i]
        columns['n_' + t + '_' + str(d) + '_km']=column

# %%
for c in columns:
    df[c] = pd.Series(columns[c])

# %%
df.to_csv(outputFile)

# %%
df.head()
# Out:
#                                    Nearest Station Code  \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore                   EW20
# Blk+97+COMMONWEALTH+CRES+Singapore                 EW20
# Blk+95+COMMONWEALTH+DR+Singapore                   EW20
# Blk+98+COMMONWEALTH+CRES+Singapore                 EW20
# Blk+93+COMMONWEALTH+DR+Singapore                   EW20
#
#                                     Vincenty Distance in km MRT Station Code  \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore                   0.356413             EW20
# Blk+97+COMMONWEALTH+CRES+Singapore                 0.544454             EW20
# Blk+95+COMMONWEALTH+DR+Singapore                   0.463413             EW20
# Blk+98+COMMONWEALTH+CRES+Singapore                 0.608135             EW20
# Blk+93+COMMONWEALTH+DR+Singapore                   0.383429             EW20
#
#                                     Walking Distance in Meters   \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore                            792
# Blk+97+COMMONWEALTH+CRES+Singapore                          828
# Blk+95+COMMONWEALTH+DR+Singapore                            725
# Blk+98+COMMONWEALTH+CRES+Singapore                          812
# Blk+93+COMMONWEALTH+DR+Singapore                            610
#
#                                     Walking Duration in Minutes  \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore                       9.883333
# Blk+97+COMMONWEALTH+CRES+Singapore                    10.516667
# Blk+95+COMMONWEALTH+DR+Singapore                       9.283333
# Blk+98+COMMONWEALTH+CRES+Singapore                    10.350000
# Blk+93+COMMONWEALTH+DR+Singapore                       7.950000
#
#                                     Station Match  Station Name     NS    EW  \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore             True  Commonwealth  False  True
# Blk+97+COMMONWEALTH+CRES+Singapore           True  Commonwealth  False  True
# Blk+95+COMMONWEALTH+DR+Singapore             True  Commonwealth  False  True
# Blk+98+COMMONWEALTH+CRES+Singapore           True  Commonwealth  False  True
# Blk+93+COMMONWEALTH+DR+Singapore             True  Commonwealth  False  True
#
#                                        CG      ...        n_supermarket_1_km  \
# HDB Address                                    ...
# Blk+83+COMMONWEALTH+CL+Singapore    False      ...                         7
# Blk+97+COMMONWEALTH+CRES+Singapore  False      ...                         6
# Blk+95+COMMONWEALTH+DR+Singapore    False      ...                         6
# Blk+98+COMMONWEALTH+CRES+Singapore  False      ...                         6
# Blk+93+COMMONWEALTH+DR+Singapore    False      ...                         7
#
#                                     n_park_1_km  n_bus_station_0.5_km  \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore              3                    10
# Blk+97+COMMONWEALTH+CRES+Singapore            2                     8
# Blk+95+COMMONWEALTH+DR+Singapore              2                    10
# Blk+98+COMMONWEALTH+CRES+Singapore            2                     8
# Blk+93+COMMONWEALTH+DR+Singapore              2                     9
#
#                                     n_subway_station_0.5_km  n_cafe_0.5_km  \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore                          1             25
# Blk+97+COMMONWEALTH+CRES+Singapore                        0             21
# Blk+95+COMMONWEALTH+DR+Singapore                          1             23
# Blk+98+COMMONWEALTH+CRES+Singapore                        0             21
# Blk+93+COMMONWEALTH+DR+Singapore                          1             24
#
#                                     n_restaurant_0.5_km  n_school_0.5_km  \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore                     39                9
# Blk+97+COMMONWEALTH+CRES+Singapore                   33                5
# Blk+95+COMMONWEALTH+DR+Singapore                     35                6
# Blk+98+COMMONWEALTH+CRES+Singapore                   33                5
# Blk+93+COMMONWEALTH+DR+Singapore                     37               11
#
#                                    n_shopping_mall_0.5_km  \
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore                        0
# Blk+97+COMMONWEALTH+CRES+Singapore                      0
# Blk+95+COMMONWEALTH+DR+Singapore                        0
# Blk+98+COMMONWEALTH+CRES+Singapore                      0
# Blk+93+COMMONWEALTH+DR+Singapore                        0
#
#                                     n_supermarket_0.5_km  n_park_0.5_km
# HDB Address
# Blk+83+COMMONWEALTH+CL+Singapore                       2              1
# Blk+97+COMMONWEALTH+CRES+Singapore                     1              0
# Blk+95+COMMONWEALTH+DR+Singapore                       1              0
# Blk+98+COMMONWEALTH+CRES+Singapore                     1              0
# Blk+93+COMMONWEALTH+DR+Singapore                       2              1
#
# [5 rows x 46 columns]

# %% [markdown]
# ## Test Codes

# %%
i = 'Blk+95+COMMONWEALTH+DR+Singapore'
d  = 1
t = 'bus_station'
name = 'n_' + t + '_' + str(d) + '_km'

print(name)
print(placeCount[d][t][i])
print(columns[name][i])
# Out:
# n_bus_station_1_km
# 39
# 39

# %%
# to see the actual names of places nearby a HDB on columns. 
i = 'Blk+93+COMMONWEALTH+DR+Singapore'
d  = 0.5
print('Places within %.1f km from %s' %(d,i))
for t in placeID[d]:
    if i in placeID[d][t]:
        print('==========================%i %s==========================' %(placeCount[d][t][i],t))
        for p in placeID[d][t][i]:
            print(p, placeDirectory[p])
    else:
        print('==========================%i %s==========================' %(0,t))
    print('==============================================================')
# Out:
# Places within 0.5 km from Blk+93+COMMONWEALTH+DR+Singapore
# ==========================9 bus_station==========================
# ChIJefkNpD8a2jERvwCryGTgxno Blk 92
# ChIJW617-T4a2jERse0GM8yi2GQ Opp Blk 95
# ChIJ7e2KUT4a2jER2OpCTN9anSk Blk 97
# ChIJkycfoEAa2jERHcZ1WoizU0M Opp Blk 115B
# ChIJAUlR2Dga2jERUsfPSEMfT-4 Opp Queensway Sec Sch
# ChIJpZZuWEca2jERnuoAA0IWrjM C'wealth Stn
# ChIJYyJzITka2jERXDjdqjOsbkU Queensway Sec Sch
# ChIJwR49YEca2jER8T1MMddBQGU C'wealth Stn
# ChIJafWljRUa2jERryMl0vEMZzk Viz Holland
# ==============================================================
# ==========================1 subway_station==========================
# ChIJhY0kWUca2jERcQr3RFss0Fg Commonwealth MRT Station
# ==============================================================
# ==========================24 cafe==========================
# ChIJPXz6sD8a2jER5AjLxp8r_Qg Noodles Stove
# ChIJg7jivT8a2jERMiC0yS_yAd0 Eng Kee: Famous Chicken Wing & Fried Bihun
# ChIJO3wUuD8a2jER2zMYHJRHrZU Big Daddy Chicken Rice
# ChIJAaaCuD8a2jERkAoBlfPUteY Cahaya Malay Food Stall
# ChIJl1w9uj8a2jERPJDhVM5bzF0 Hotspot western
# ChIJf866wD8a2jERCH9N47_Wttg Selera Tiga Puteri Malay Food Stall
# ChIJWfwzxz8a2jERsJx9R33fW14 SK Noodle House
# ChIJbwbTwD8a2jERhHtgpe2B7hk David's Laksa & Mee Siam
# ChIJmx2Lxj8a2jERz0XvjouUO1E 101 Coffee Stall
# ChIJAQAAkEAa2jER3G3AamaJnQk Original Teochew Braised Duck
# ChIJnfMHn0Aa2jERbMsINwo6Flw Ming Lock Cafe
# ChIJLwV03D8a2jER7yRgi5JTvvU Bao Fa Traditional Kitchen
# ChIJLwV03D8a2jERRFK7MBuwXF4 Sin Kee Heong
# ChIJAQAAkEAa2jERySdXuLQXl_8 Cheng's Local Delights
# ChIJAQAAkEAa2jERqxFXSJS4n_Y Natasha Malay Food
# ChIJAQAAkEAa2jER8FBRYteRV7I Fishball Minced Meat Noodle
# ChIJAQAAkEAa2jER7uJUgV2NmmY Shanghai 8 Treasures Vegetarian Food
# ChIJAQAAkEAa2jERX_t8KC13wS8 Foo Kee Curry Puff and Chee Cheong Fun
# ChIJAQAAkEAa2jERUE6L2Mvv3Ss Indian Muslim Food
# ChIJRy1eOEAa2jERovGBR5Lg6dU First stop cafe 7
# ChIJJ5FWa0Aa2jER7VYxZIQe4zQ 1st stop Coffee shop
# ChIJNZpS8kAa2jERu5vEyTzJUjo Commonwealth Cafe
# ChIJRb26wUAa2jERomlf9usWKZ8 Cars and Coffee Singapore
# ChIJ5SvsYkca2jERW6052mxj3k0 Green Vegetarian
# ==============================================================
# ==========================37 restaurant==========================
# ChIJAVyFvD8a2jER4XthyvE5SRk Hong Kong Street Old Chun Kee Restaurant
# ChIJ3ZFJuT8a2jERQUTmdcLod7E Hanuman Thai Cuisine
# ChIJdWwDsj8a2jERXK_Z9k7-Ar8 Katong Laksa 88
# ChIJ9cdHuT8a2jEROEtiLkdUkxQ Mei Yee Teochew Fish Ball Noodle
# ChIJZ3z7rj8a2jERh2xxbdKNiJE Hok Sing Eating House
# ChIJCVuGxz8a2jERN05klj7ZwB0 Dessert AUNTY Commonwealth Food Centre
# ChIJPyA_xz8a2jERvOHS4MqWVs0 SENG KEE CHICKEN RICE 新奇鸡饭
# ChIJvTS0wD8a2jER0P2ewbcEbFo Mela Food Junction
# ChIJO5xBxz8a2jER99PdqkviwOo Huang Da Fu 黄大福 Bak Chor Mee
# ChIJLwV03D8a2jERnYztFqKUX0w Jian Kang Noodles
# ChIJjbH6rj8a2jERFSEXk8L9_wY Commonwealth Crescent Market and Food Centre
# ChIJcxslxz8a2jERAkAdnRNlXQ4 Olde Laksa
# ChIJq5vgxz8a2jERFxW_UBJAUFI 喜乐亭
# ChIJC6u2xz8a2jERFgQux740UwI Yu Wei Ren Sheng fish soup
# ChIJEWj9xj8a2jER3CCsQkxEpm8 HK Street Chun Kee 香港街珍记
# ChIJT0JZtz8a2jERNDNFhdUfn3o Fai Kee Fishhead Bee Hoon
# ChIJD3l3yD8a2jERyZotihmSXFQ 牛车水阿婆卤鸭
# ChIJG9GVwT8a2jERUVhZ6Dc4qYI Stall 73
# ChIJLwV03D8a2jERkyjk1bGYyao Henry's Chicken Rice
# ChIJnT4yxj8a2jERfwgsWjrQzqo 100号 Laksa and Prawn Noodle
# ChIJLwV03D8a2jER10MNhZF52QM Hong Kee Porridge
# ChIJx6-Vxj8a2jERwBpbPly1TMM 93 Curry Chicken Noodle
# ChIJFWgEADoa2jERJPEh5qE1rV8 Queenstown Poh Pia (Skin)
# ChIJG9GVwT8a2jERvxDHau3hggQ Two Chefs
# ChIJO1aAwT8a2jERKqpq3I9t4oQ Swee Hin Restaurant
# ChIJ90YlnkAa2jERBmbGtpCUuic Guru's Banana Leaf Cuisine Pte. Ltd.
# ChIJHYGdm0Aa2jERzR4l2zB38yg Aylwin Holdings
# ChIJh-I_pEAa2jERnqxW8uzCk9k Meixi’s Kitchen Yong Tau Foo 美茜酿豆腐
# ChIJPSA82z4a2jERUSq0TkWkuCw Thai Village Restaurant & bar
# ChIJGdIiwD4a2jERJm39sI0nkik McDonald's Ridout
# ChIJv05uhkAa2jERsdpIcD6LeW4 Central Ocean International Pte Ltd
# ChIJLwV03D8a2jER_x5evVfzMLE Jia Yuan Vegetarian Food
# ChIJ1-OsOD4a2jERSGV-emDB6hE Delifrance Singapore - Queensway Cheers 1 Express Corner
# ChIJ61WJnQ4Z2jERgYB4BkwtlrY Ysq International Pte. Ltd.
# ChIJYV0oPkAa2jER47Y0mEskXOY Madam Leong Ban Mian
# ChIJRy1eOEAa2jERlFdlb3AwGJU HongKong Street Zhizhar
# ChIJAQ7pY0ca2jER7xzgrF89bcs Long John Silver's
# ==============================================================
# ==========================11 school==========================
# ChIJ42uAnD8a2jERoVRF4aCTsMg Queenstown Lutheran Church Kindergarten
# ChIJRQt7zj8a2jER9bTd8rWcyDA Vietnam Language Centre
# ChIJUYwHk0Aa2jERaD1H3yOaEvE Primary Care Academy
# ChIJx-nrBUAa2jERPOHOXIrB8Qo ACS International
# ChIJw9yEOEAa2jER0dbTq9vNfWQ PCF Sparkletots Buona Vista Kindergarten
# ChIJq6qqqmcZ2jERnmBg6WoXr6o CHIJ Primary School (Kellock)
# ChIJr9n8N0ca2jERXorpy3cltZk Faith Kindergarten
# ChIJ43CswUAa2jERQocbxyZ_qyE CreativeBITS
# ChIJRZkvrmoa2jER_xTfaLvhePs Beethoven Creative Music & Art
# ChIJvwXMzUAa2jERz2nP2vt6QbM Agape Little Uni @ Haw Par
# ChIJ42CR00Aa2jERaYOSxT-ECWQ Queenstown PAP Community Foundation
# ==============================================================
# ==========================0 shopping_mall==========================
# ==============================================================
# ==========================2 supermarket==========================
# ChIJr_Tkm0Aa2jER0niHTVyfpTQ Kodak Color Center
# ChIJVYEAaEca2jERpxajHtlWFRE Sheng Siong
# ==============================================================
# ==========================1 park==========================
# ChIJGeLxgTga2jERjqQhboMiQBw Rooftop Garden Blk 88
# ==============================================================
