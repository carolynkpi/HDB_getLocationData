# %% [markdown]
# # Step 1a: Get Coordinates for MRT Stations

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import requests
import json as json
import time
import csv

from myFunctions import *
keys = getKeys('GoogleAPIKey.txt')

# %% [markdown]
# ## User Inputs
# I like to date my output files so that I don't accidentally overwrite files of my previous runs. For more automated systems, it should be quite simple to append today's date to the filename. A function will be needed to append a version number to the date if there is already a file with the same name in the directory. But for developmental purposes, it is better to have the user manually change this so that the user knows what he/she is doing.
#
# The data file is 'MRT.csv' which I modified from a list from Wikipedia.

# %%
dataFile = 'MRT.csv'
outputFile = 'MRT_address_latlong_20180307.csv'
outputFailureFile = 'MRT_address_latlong_failed_20180307.csv'

# %% [markdown]
# ## Get Station Addresses to Query
# MRT addresses are created and stored as a dictionary to be queried later. <br>
# The data frame that is read from the data file is preserved to:
# - contain all required columns.
# - be indexed by Station Code.
#
# This is so that details of failed requests can be accessed from this data frame and saved to a failure file.  The failure file can thus be re-run with this same code later.

# %%
mrt = pd.read_csv(dataFile)
mrt.loc[mrt['LRT/MRT'] == 'Both','LRT/MRT'] = 'MRT'
print('Number of stations: ', len(mrt))

# Create address format. 
address = ('Singapore ' + mrt['Station Name'] + ' ' + mrt['LRT/MRT']).tolist()
address = ['+'.join(i.split(' '))for i in address]
index = mrt['Station Code'].tolist()

# Comment out the following 2 lines for full run
#index = index[20:25]
#address = address[20:25]

# Create address dictionary to query.
address = dict(zip(index, address))

# Preserve mrt for failure retry later
mrt = mrt.loc[:, ['Station Code', 'Station Name', 'LRT/MRT']]
mrt.set_index('Station Code', inplace = True)
# Out:
# Number of stations:  190

# %% [markdown]
# Since there are only 190 stations, this code can be run in a single run. There is no need to split the query.

# %% [markdown]
# ## API Query
# The outermost ***with*** loop ensures that retrieved data are all written to a file if the code is interrupted.
#
# The ***success*** and ***failure*** dictionaries store the coordinate/error for each address. This is to ease troubleshooting. In the event that these dictionaries take up too much memory space, the ***success*** dictionary can be removed because the data are already written to file in the ***with*** loop. However, the ***failure*** dictinary needs to be kept as the data are converted to a data frame and file at the end of the code.
#
# Because the naming of MRT stations in Google Maps are not standardized (especially for LRT stations and stations that are building-in-progress), the query may not always return a valid result. For each of such failure cases, the code will attempt to query the API again up to 2 other possible address formats. If there are still failure cases after the 3 formats, a manual intervention is required to check the coordinates on Google Maps on a browser.

# %%
success = {}
failure = {}

url = 'https://maps.googleapis.com/maps/api/geocode/json?'

# %%
with open(outputFile, 'w', newline = '', encoding = 'utf-8') as output:
    writer = csv.writer(output, delimiter=',')
    writer.writerow(['Station Code', 'Station Address', 'Latitude', 'Longtitude', 'latlong'])
    
    # First Attempt
    for i in address:
        params = {'key' : keys['GoogleMapsGeocoding'],'address': address[i] }
        paramString = getParamString(params)
        reqStatus, returnedStatus, data, tries = tryGET(3,url+paramString)

        if reqStatus == 200 and returnedStatus == 'OK':
            lat = data['results'][0]['geometry']['location']['lat']
            long = data['results'][0]['geometry']['location']['lng']
            success[i] = (lat,long)
            writer.writerow([i, address[i], lat, long, str(lat) + ',' + str(long)])
            print(i, ' Geocoding succeeded.')
        else:
            failure[i] = (mrt.loc[i,'Station Name'], mrt.loc[i,'LRT/MRT'], reqStatus, returnedStatus)
            print(i, 'Geocoding failed after ', tries, ' tries.')
            print(reqStatus, returnedStatus)
            
    print('Number of success after first attempt: ', len(success))
    print('Number of failures after first attempt: ', len(failure))
    
    # Second Attempt
    retrySucceed = []
    if len(failure)!=0: 
        print('Retry geocoding with MRT/LRT station.')
        for i in failure: 
            address[i] = '+'.join(address[i].split('+')[:-1])
            address[i] = address[i] + '+MRT/LRT+station'
            params = {'key' : keys['GoogleMapsGeocoding'],'address': address[i] }
            paramString = getParamString(params)
            reqStatus, returnedStatus, data, tries = tryGET(3,url+paramString, sleep = 2)
        
            if reqStatus == 200 and returnedStatus == 'OK':
                lat = data['results'][0]['geometry']['location']['lat']
                long = data['results'][0]['geometry']['location']['lng']
                success[i] = (lat,long)
                writer.writerow([i, address[i], lat, long, str(lat) + ',' + str(long)])
                print(i, ' Geocoding succeeded.')
                retrySucceed.append(i)
            else:
                failure[i] = (mrt.loc[i,'Station Name'], mrt.loc[i,'LRT/MRT'], reqStatus, returnedStatus)
                print(i, 'Geocoding failed after ', tries, ' tries.')
                print(reqStatus, returnedStatus)    

    for i in retrySucceed: 
        del failure[i]
    
    print('Number of success after second attempt: ', len(success))
    print('Number of failures after second attempt: ', len(failure))
    
    # Third Attempt
    retrySucceed = []
    if len(failure)!=0: 
        print('Retry geocoding with Light Rail Station.')
        for i in failure: 
            address[i] = '+'.join(address[i].split('+')[:-2])
            address[i] = address[i] + '+Light+Rail+Station'        
            params = {'key' : keys['GoogleMapsGeocoding'],'address': address[i] }
            paramString = getParamString(params)
            reqStatus, returnedStatus, data, tries = tryGET(3,url+paramString, sleep = 2)
        
            if reqStatus == 200 and returnedStatus == 'OK':
                lat = data['results'][0]['geometry']['location']['lat']
                long = data['results'][0]['geometry']['location']['lng']
                success[i] = (lat,long)
                writer.writerow([i, address[i], lat, long, str(lat) + ',' + str(long)])
                print(i, ' Geocoding succeeded.')
                retrySucceed.append(i)
            else:
                failure[i] = (mrt.loc[i,'Station Name'], mrt.loc[i,'LRT/MRT'], reqStatus, returnedStatus)
                print(i, 'Geocoding failed after ', tries, ' tries.')
                print(reqStatus, returnedStatus)    

    for i in retrySucceed: 
        del failure[i]
    
    print('Number of success: ', len(success))
    print('Number of failures: ', len(failure))
# Out:
# Try: 1.
# NS10  Geocoding succeeded.
# Try: 1.
# EW9  Geocoding succeeded.
# Try: 1.
# NS16  Geocoding succeeded.
# Try: 1.
# SE3  Geocoding succeeded.
# Try: 1.
# BP9  Geocoding succeeded.
# Try: 1.
# CC12  Geocoding succeeded.
# Try: 1.
# CE1 DT16  Geocoding succeeded.
# Try: 1.
# TE29  Geocoding succeeded.
# Try: 1.
# DT5  Geocoding succeeded.
# Try: 1.
# EW5  Geocoding succeeded.
# Try: 1.
# DT29  Geocoding succeeded.
# Try: 1.
# DT30  Geocoding succeeded.
# Try: 1.
# TE30  Geocoding succeeded.
# Try: 1.
# DT21  Geocoding succeeded.
# Try: 1.
# DT23  Geocoding succeeded.
# Try: 1.
# NS17 CC15  Geocoding succeeded.
# Try: 1.
# NE9  Geocoding succeeded.
# Try: 1.
# EW27  Geocoding succeeded.
# Try: 1.
# CC19 DT9  Geocoding succeeded.
# Try: 1.
# NS18  Geocoding succeeded.
# Try: 1.
# CC2  Geocoding succeeded.
# Try: 1.
# TE7  Geocoding succeeded.
# Try: 1.
# NE15  Geocoding succeeded.
# Try: 1.
# EW12 DT14  Geocoding succeeded.
# Try: 1.
# NS2  Geocoding succeeded.
# Try: 1.
# CC18  Geocoding succeeded.
# Try: 1.
# NS3  Geocoding succeeded.
# Try: 1.
# DT1 BP6  Geocoding succeeded.
# Try: 1.
# EW21 CC22  Geocoding succeeded.
# Try: 1.
# CC17 TE9  Geocoding succeeded.
# Try: 1.
# NS12  Geocoding succeeded.
# Try: 1.
# CC31  Geocoding succeeded.
# Try: 1.
# DT2  Geocoding succeeded.
# Try: 1.
# CG2  Geocoding succeeded.
# Try: 1.
# SW1  Geocoding succeeded.
# Try: 1.
# NE4 DT19  Geocoding succeeded.
# Try: 1.
# EW25  Geocoding succeeded.
# Try: 1.
# NS4 BP1  Geocoding succeeded.
# Try: 1.
# NS25 EW13  Geocoding succeeded.
# Try: 1.
# NE5  Geocoding succeeded.
# Try: 1.
# EW23  Geocoding succeeded.
# Try: 1.
# EW20  Geocoding succeeded.
# Try: 1.
# SE1  Geocoding succeeded.
# Try: 1.
# PE3  Geocoding succeeded.
# Try: 1.
# PE1  Geocoding succeeded.
# Try: 1.
# CC8  Geocoding succeeded.
# Try: 1.
# PE7  Geocoding succeeded.
# Try: 1.
# NS24 NE6 CC1  Geocoding succeeded.
# Try: 1.
# EW22  Geocoding succeeded.
# Try: 1.
# DT17  Geocoding succeeded.
# Try: 1.
# CC3  Geocoding succeeded.
# Try: 1.
# EW7  Geocoding succeeded.
# Try: 1.
# CG1 DT35  Geocoding succeeded.
# Try: 1.
# BP10  Geocoding succeeded.
# Try: 1.
# SW2  Geocoding succeeded.
# Try: 1.
# NE8  Geocoding succeeded.
# Try: 1.
# CC20  Geocoding succeeded.
# Try: 1.
# SW5  Geocoding succeeded.
# Try: 1.
# DT20  Geocoding succeeded.
# Try: 1.
# TE22  Geocoding succeeded.
# Try: 1.
# DT24  Geocoding succeeded.
# Try: 1.
# TE15  Geocoding succeeded.
# Try: 1.
# EW30  Geocoding succeeded.
# Try: 1.
# NE1 CC29  Geocoding succeeded.
# Try: 1.
# TE16  Geocoding succeeded.
# Try: 1.
# CC25  Geocoding succeeded.
# Try: 1.
# DT3  Geocoding succeeded.
# Try: 1.
# CC21  Geocoding succeeded.
# Try: 1.
# NE14  Geocoding succeeded.
# Try: 1.
# DT22  Geocoding succeeded.
# Try: 1.
# BP12  Geocoding succeeded.
# Try: 1.
# EW29  Geocoding succeeded.
# Try: 1.
# NS1 EW24  Geocoding succeeded.
# Try: 1.
# PE5  Geocoding succeeded.
# Try: 1.
# DT28  Geocoding succeeded.
# Try: 1.
# EW10  Geocoding succeeded.
# Try: 1.
# SE4  Geocoding succeeded.
# Try: 1.
# TE24  Geocoding succeeded.
# Try: 1.
# BP3  Geocoding succeeded.
# Try: 1.
# EW6  Geocoding succeeded.
# Try: 1.
# CC24  Geocoding succeeded.
# Try: 1.
# CC30  Geocoding succeeded.
# Try: 1.
# NS14  Geocoding succeeded.
# Try: 1.
# DT6  Geocoding succeeded.
# Try: 1.
# NE13  Geocoding succeeded.
# Try: 1.
# NS7  Geocoding succeeded.
# Try: 1.
# SW3  Geocoding succeeded.
# Try: 1.
# CC27  Geocoding succeeded.
# Try: 1.
# EW26  Geocoding succeeded.
# Try: 1.
# EW11  Geocoding succeeded.
# Try: 1.
# SW6  Geocoding succeeded.
# Try: 1.
# TE5  Geocoding succeeded.
# Try: 1.
# NE7 DT12  Geocoding succeeded.
# Try: 1.
# CC14  Geocoding succeeded.
# Try: 1.
# CC10 DT26  Geocoding succeeded.
# Try: 1.
# NS27 CE2 TE20  Geocoding succeeded.
# Try: 1.
# TE21  Geocoding succeeded.
# Try: 1.
# NS28  Geocoding succeeded.
# Try: 1.
# TE26  Geocoding succeeded.
# Try: 1.
# TE27  Geocoding succeeded.
# Try: 1.
# NS8  Geocoding succeeded.
# Try: 1.
# CC16  Geocoding succeeded.
# Try: 1.
# DT25  Geocoding succeeded.
# Try: 1.
# TE18  Geocoding succeeded.
# Try: 1.
# TE6  Geocoding succeeded.
# Try: 1.
# PE2  Geocoding succeeded.
# Try: 1.
# TE10  Geocoding succeeded.
# Try: 1.
# CC7  Geocoding succeeded.
# Try: 1.
# TE12  Geocoding succeeded.
# Try: 1.
# NS21 DT11  Geocoding succeeded.
# Try: 1.
# PW5  Geocoding succeeded.
# Try: 1.
# CC5  Geocoding succeeded.
# Try: 1.
# NS20  Geocoding succeeded.
# Try: 1.
# PE6  Geocoding succeeded.
# Try: 1.
# CC23  Geocoding succeeded.
# Try: 1.
# NS22 TE14  Geocoding succeeded.
# Try: 1.
# TE13  Geocoding succeeded.
# Try: 1.
# EW16 NE3 TE17  Geocoding succeeded.
# Try: 1.
# CC26  Geocoding succeeded.
# Try: 1.
# EW1  Geocoding succeeded.
# Try: 1.
# EW8 CC9  Geocoding succeeded.
# Try: 1.
# BP8  Geocoding succeeded.
# Try: 1.
# BP7  Geocoding succeeded.
# Try: 1.
# BP5  Geocoding succeeded.
# Try: 1.
# EW28  Geocoding succeeded.
# Try: 1.
# NE10  Geocoding succeeded.
# Try: 1.
# CC32  Geocoding succeeded.
# Try: 1.
# CC4 DT15  Geocoding succeeded.
# Try: 1.
# NE17 PTC  Geocoding succeeded.
# Try: 1.
# NE18  Geocoding succeeded.
# Try: 1.
# PW3  Geocoding succeeded.
# Try: 1.
# EW19  Geocoding succeeded.
# Try: 1.
# NS26 EW14  Geocoding succeeded.
# Try: 1.
# SE5  Geocoding succeeded.
# Try: 1.
# EW18  Geocoding succeeded.
# Try: 1.
# SW8  Geocoding succeeded.
# Try: 1.
# PE4  Geocoding succeeded.
# Try: 1.
# DT13  Geocoding succeeded.
# Try: 1.
# SE2  Geocoding succeeded.
# Try: 1.
# PW1  Geocoding succeeded.
# Try: 1.
# Try: 2.
# Try: 3.
# PW4 Geocoding failed after  3  tries.
# 200 ZERO_RESULTS
# Try: 1.
# BP11  Geocoding succeeded.
# Try: 1.
# NS11  Geocoding succeeded.
# Try: 1.
# NE16 STC  Geocoding succeeded.
# Try: 1.
# BP13  Geocoding succeeded.
# Try: 1.
# NE12 CC13  Geocoding succeeded.
# Try: 1.
# TE19  Geocoding succeeded.
# Try: 1.
# TE28  Geocoding succeeded.
# Try: 1.
# EW3  Geocoding succeeded.
# Try: 1.
# DT7  Geocoding succeeded.
# Try: 1.
# NS23  Geocoding succeeded.
# Try: 1.
# PW7  Geocoding succeeded.
# Try: 1.
# BP2  Geocoding succeeded.
# Try: 1.
# TE4  Geocoding succeeded.
# Try: 1.
# CC6  Geocoding succeeded.
# Try: 1.
# DT10 TE11  Geocoding succeeded.
# Try: 1.
# PW6  Geocoding succeeded.
# Try: 1.
# DT37 TE31  Geocoding succeeded.
# Try: 1.
# CC11  Geocoding succeeded.
# Try: 1.
# EW2 DT32  Geocoding succeeded.
# Try: 1.
# DT33  Geocoding succeeded.
# Try: 1.
# DT31  Geocoding succeeded.
# Try: 1.
# DT8  Geocoding succeeded.
# Try: 1.
# EW4 CG  Geocoding succeeded.
# Try: 1.
# TE25  Geocoding succeeded.
# Try: 1.
# EW15  Geocoding succeeded.
# Try: 1.
# TE23  Geocoding succeeded.
# Try: 1.
# Try: 2.
# Try: 3.
# PW2 Geocoding failed after  3  tries.
# 200 ZERO_RESULTS
# Try: 1.
# BP4  Geocoding succeeded.
# Try: 1.
# DT18  Geocoding succeeded.
# Try: 1.
# CC28  Geocoding succeeded.
# Try: 1.
# BP14  Geocoding succeeded.
# Try: 1.
# SW4  Geocoding succeeded.
# Try: 1.
# EW17  Geocoding succeeded.
# Try: 1.
# NS19  Geocoding succeeded.
# Try: 1.
# SW7  Geocoding succeeded.
# Try: 1.
# EW31  Geocoding succeeded.
# Try: 1.
# EW33  Geocoding succeeded.
# Try: 1.
# EW32  Geocoding succeeded.
# Try: 1.
# DT27  Geocoding succeeded.
# Try: 1.
# DT34  Geocoding succeeded.
# Try: 1.
# TE8  Geocoding succeeded.
# Try: 1.
# NS9 TE2  Geocoding succeeded.
# Try: 1.
# TE1  Geocoding succeeded.
# Try: 1.
# TE3  Geocoding succeeded.
# Try: 1.
# NE11  Geocoding succeeded.
# Try: 1.
# DT36  Geocoding succeeded.
# Try: 1.
# NS5  Geocoding succeeded.
# Try: 1.
# NS15  Geocoding succeeded.
# Try: 1.
# NS13  Geocoding succeeded.
# Number of success after first attempt:  188
# Number of failures after first attempt:  2
# Retry geocoding with MRT/LRT station.
# Try: 1.
# PW4  Geocoding succeeded.
# Try: 1.
# PW2  Geocoding succeeded.
# Number of success after second attempt:  190
# Number of failures after second attempt:  0
# Number of success:  190
# Number of failures:  0

# %% [markdown]
# ## Save Failure Data

# %%
if len(failure)!=0:
    failure = pd.DataFrame.from_dict(failure, orient = 'Index')
    failure.reset_index(level=0, inplace=True)
    failure.columns = ['Station Code', 'Station Name', 'LRT/MRT', 'reqStatus', 'returnedStatus']
    failure.to_csv(outputFailureFile, index = False)
